# %% [markdown]
# <a href="https://colab.research.google.com/github/Atharva-2007/DSBDA/blob/main/Assignment10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/IRIS.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.histplot(df["sepal_length"],kde=True)
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(df["sepal_width"],kde=True)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(df["petal_length"],kde=True)
# Out:
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
sns.histplot(df["petal_width"],kde=True)
# Out:
# <Axes: xlabel='petal_width', ylabel='Count'>

# %%
sns.boxplot(data=df, x="sepal_length", y="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.boxplot(data=df, x="sepal_width", y="species")
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.boxplot(data=df, x="petal_length", y="species")
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.boxplot(data=df, x="petal_width", y="species")
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>
